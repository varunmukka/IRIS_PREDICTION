# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
cam=cv2.imread("C:/Users/STUDENT/Desktop/college.png")

# %%
# !pip install opencv-python

# %%
print(cam)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[ 33  92 102]
#   [ 43 103 115]
#   [ 88 146 165]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[ 41 101 107]
#   [ 45 104 114]
#   [ 62 119 140]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[ 38  95 117]
#   [ 34  89 116]
#   [ 32  82 118]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
import pandas as pd

# %%
college=pd.read_csv("C:/Users/STUDENT/Desktop/labels_my-project-name_2023-08-03-11-37-36.csv")

# %%
college.head()
# Out:
#   label_name  bbox_x  bbox_y  bbox_width  bbox_height   image_name  \
# 0       tree     169     437         723          295  college.png
# 1    college      94     194         629          228  college.png
# 2    college      28     292         193          161  college.png
# 3       tree      16     555          98          161  college.png
#
#    image_width  image_height
# 0         1360           753
# 1         1360           753
# 2         1360           753
# 3         1360           753

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    4 non-null      object
#  1   bbox_x        4 non-null      int64
#  2   bbox_y        4 non-null      int64
#  3   bbox_width    4 non-null      int64
#  4   bbox_height   4 non-null      int64
#  5   image_name    4 non-null      object
#  6   image_width   4 non-null      int64
#  7   image_height  4 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 384.0+ bytes

# %%
college.sum()
# Out:
# label_name                            treecollegecollegetree
# bbox_x                                                   307
# bbox_y                                                  1478
# bbox_width                                              1643
# bbox_height                                              845
# image_name      college.pngcollege.pngcollege.pngcollege.png
# image_width                                             5440
# image_height                                            3012
# dtype: object

# %%
college.isnull().sum()
# Out:
# label_name      0
# bbox_x          0
# bbox_y          0
# bbox_width      0
# bbox_height     0
# image_name      0
# image_width     0
# image_height    0
# dtype: int64

# %%
college.dropna
# Out:
# <bound method DataFrame.dropna of   label_name  bbox_x  bbox_y  bbox_width  bbox_height   image_name  \
# 0       tree     169     437         723          295  college.png
# 1    college      94     194         629          228  college.png
# 2    college      28     292         193          161  college.png
# 3       tree      16     555          98          161  college.png
#
#    image_width  image_height
# 0         1360           753
# 1         1360           753
# 2         1360           753
# 3         1360           753  >

# %%
college.describe()
# Out:
#            bbox_x      bbox_y  bbox_width  bbox_height  image_width  \
# count    4.000000    4.000000    4.000000     4.000000          4.0
# mean    76.750000  369.500000  410.750000   211.250000       1360.0
# std     70.414842  158.926608  311.105957    64.147616          0.0
# min     16.000000  194.000000   98.000000   161.000000       1360.0
# 25%     25.000000  267.500000  169.250000   161.000000       1360.0
# 50%     61.000000  364.500000  411.000000   194.500000       1360.0
# 75%    112.750000  466.500000  652.500000   244.750000       1360.0
# max    169.000000  555.000000  723.000000   295.000000       1360.0
#
#        image_height
# count           4.0
# mean          753.0
# std             0.0
# min           753.0
# 25%           753.0
# 50%           753.0
# 75%           753.0
# max           753.0

# %%
college.dropna
# Out:
# <bound method DataFrame.dropna of   label_name  bbox_x  bbox_y  bbox_width  bbox_height   image_name  \
# 0       tree     169     437         723          295  college.png
# 1    college      94     194         629          228  college.png
# 2    college      28     292         193          161  college.png
# 3       tree      16     555          98          161  college.png
#
#    image_width  image_height
# 0         1360           753
# 1         1360           753
# 2         1360           753
# 3         1360           753  >

# %%
import seaborn as sns

# %%
sns.pairplot(college)

# %%
k=sns.boxplot(data=college)

# %%
sns.jointplot(data=college)

# %%
sns.displot(data=college )

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
testing=img.imread("C:/Users/STUDENT/Desktop/college.PNG")
plt.imshow(testing)

# %%
sns.displot(data=college)

# %%
import cv2

# %%
Start_point=(4,4)
End_point=(220,220)
color=(255,0,0)
thickness=9

# %%
testing=cv2.rectangle(testing,Start_point,End_point,color,thickness)

# %%
cv2.imshow("name",testing)
cv2.waitKey(0)

# %%
#gray=cv2.cvtcolor(college,cv2.COLOR_BGR2GRAY)
